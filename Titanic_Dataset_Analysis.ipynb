# %% [markdown]
# # **Titanic Dataset Analysis**

# %% [markdown]
# This project involves analyzing the Titanic dataset using Python and pandas. The goal is to explore, clean, and visualize the data, followed by feature engineering and model evaluation.

# %% [markdown]
# **Setup and Libraries**
#
# Before we begin, ensure all necessary libraries are imported. If you’re using Google Colab, the following cells guide you through mounting your Google Drive and installing any required packages.

# %%
import pandas as pd

# %%
'''
Linking google colab to the drive folder
'''
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
'''
Place the csv files inside your drive and then run this cell
'''
# %cd /content/gdrive/My\ Drive/
# Out:
# /content/gdrive/My Drive/DSredo/Assignment1/Part1

# %% [markdown]
# # **Data Import and Overview**

# %% [markdown]
# We start by importing the dataset and taking an initial look at its structure.

# %%
df=pd.read_csv('top_50_restaurants.csv')
df
# Out:
# A1_1.ipynb  top_50_restaurants.csv
#     Year  Ranking                              Name              City  \
# 0   2018        1               Osteria Francescana            Modena
# 1   2018        2             El Celler de Can Roca            Girona
# 2   2018        3                           Mirazur            Menton
# 3   2018        4               Eleven Madison Park          New York
# 4   2018        5                            Gaggan           Bangkok
# 5   2018        6                           Central              Lima
# 6   2018        7                             Maido              Lima
# 7   2018        8                            Arpège             Paris
# 8   2018        9                          Mugaritz     San Sebastian
# 9   2018       10                  Asador Etxebarri              Axpe
# 10  2018       11                         Quintonil       Mexico City
# 11  2018       12          Blue Hill at Stone Barns   Pocantico Hills
# ...

# %% [markdown]
# **Exploring the Dataset**
#
# *Viewing Initial Records*
#
# Let’s take a quick look at the first few and last few rows of the dataset.

# %%
df.head()
# Out:
#    Year  Ranking                   Name      City   Country  Latitude  \
# 0  2018        1    Osteria Francescana    Modena     Italy   44.6431
# 1  2018        2  El Celler de Can Roca    Girona     Spain   41.9808
# 2  2018        3                Mirazur    Menton    France   43.7747
# 3  2018        4    Eleven Madison Park  New York       USA   40.7146
# 4  2018        5                 Gaggan   Bangkok  Thailand   13.7500
#
#    Longitude
# 0    10.9341
# 1     2.8187
# 2     7.5046
# 3   -74.0071
# 4   100.5160

# %% [markdown]
# Last five rows:

# %%
df.tail()
# Out:
#     Year  Ranking                  Name           City       Country  \
# 45  2018       46                Saison  San Francisco           USA
# 46  2018       47  Schloss Schauenstein      Fürstenau   Switzerland
# 47  2018       48           Hiša Franko        Kobarid      Slovenia
# 48  2018       49                  Nahm        Bangkok      Thailand
# 49  2018       50      The Test Kitchen      Cape Town  South Africa
#
#      Latitude   Longitude
# 45  37.777100 -122.419600
# 46  46.716667    9.433333
# 47  46.246436   13.578006
# 48  13.750000  100.516000
# 49 -33.916000   18.416000

# %% [markdown]
# **The most popular in the list of top 50 restaurants**

# %%
df['Country'].value_counts().idxmax()
# Out:
# 'Spain'

# %% [markdown]
# **The most popular in the list of top 50 restaurants**

# %%
df['City'].value_counts().idxmax()
# Out:
# 'London'

# %% [markdown]
# **Filtering the Dataset**
#
#
# Restaurants Ranked Between 35 and 40 (Exclusive)

# %%
df.iloc[35:39]
# Out:
#     Year  Ranking                 Name              City  Country   Latitude  \
# 35  2018       36                Reale  Castel di Sangro    Italy  41.783333
# 36  2018       37  Restaurant Tim Raue            Berlin  Germany  52.516100
# 37  2018       38               Lyle's            London       UK  51.506400
# 38  2018       39      Astrid y Gastón              Lima     Peru -12.043000
#
#     Longitude
# 35    14.1000
# 36    13.3770
# 37    -0.1272
# 38   -77.0280

# %% [markdown]
# **Printing the dataframe with restaurants ranking 20-30 (inclusive of 20 and 30) in UK, USA and Spain.**

# %%
df_filtered=df[df['Country'].isin(['UK', 'USA', 'Spain'])]
df_filtered[(df_filtered['Ranking']>=20) & (df_filtered['Ranking']<=30)]
# Out:
#     Year  Ranking          Name      City Country  Latitude  Longitude
# 24  2018       25         Cosme  New York     USA   40.7146   -74.0071
# 25  2018       26  Le Bernardin  New York     USA   40.7146   -74.0071

# %% [markdown]
# **Comparative Analysis**
#
#
# *Comparing Peru and Japan*
#
# Let's compare if Peru has more restaurants in the list than to Japan.

# %%
per=df[df['Country']=='Peru'].count()['Name']
jap =df[df['Country']=='Japan'].count()['Name']

per>jap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-85f13ca9c461> in <cell line: 1>()
# ----> 1 per=df[df['Country']=='Peru'].count()['Name']
#       2 jap =df[df['Country']=='Japan'].count()['Name']
#       3
#       4 per>jap
#
# NameError: name 'df' is not defined
